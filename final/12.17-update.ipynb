# %% [markdown]
# # Final Project
# ### Group Members: Gege Li, Xiaojia He
#
#
# #### The project mainly focuses on the information of personal income and expenditure in New York, so that we can know the living standard of NY. The project contains two parts: income and expenditure. In each part we plan to do some data analysis and EDA. Finally, we will get a overall conclusion about our research. The data comes from three different sources, for income data we download the csv files in one website, for expenditure data we use web API and  scraping the website into html file.
#
#
# ### Income data analysis in New York

# %%
# import all the modules that we need in this project
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import geocoder
import folium

# %% [markdown]
# #### Part 1: Income by gender

# %%
# Download the csv data from website and upload to Github
# Read the csv file from Gibhit
gender = pd.read_csv('https://raw.githubusercontent.com/gegeli638/DAV-5400/master/final/Wage%20by%20Gender%20in%20Common%20Jobs.csv')

# to clean and transfer the data, we need to drop the data that we do not need 
gender = gender.drop(columns = ['ID Year','ID Gender', 'Employment Time Status','ID Employment Time Status','ID Detailed Occupation','Average Wage Appx MOE','Total Population MOE Appx', 'Record Count','ID Geography'])

# use gender.head() to print the answer
gender.head()
# Out:
#    Gender  Year                        Detailed Occupation  Average Wage  \
# 0    Male  2017                        Retail salespersons  50004.664322
# 1  Female  2017                        Retail salespersons  41425.703378
# 2  Female  2017  Nursing, psychiatric, & home health aides  29463.650346
# 3  Female  2017                     Miscellaneous managers  97162.749970
# 4  Female  2017        Elementary & middle school teachers  69458.339533
#
#    Total Population Geography
# 0             70791  New York
# 1             50084  New York
# 2            151487  New York
# 3             91553  New York
# 4            187210  New York

# %%
# use groupby to get the Average Wage of male and female separately in different years
gender.groupby(['Year', 'Gender'])['Average Wage'].mean()
# Out:
# Year  Gender
# 2014  Female    52758.135608
#       Male      65888.677753
# 2015  Female    52637.719147
#       Male      64293.934503
# 2016  Female    54569.377438
#       Male      65882.567252
# 2017  Female    56818.266326
#       Male      68020.220297
# Name: Average Wage, dtype: float64

# %% [markdown]
# From this statistical analysis, we can see in each year male income is more than female. And from 2014 to 2017, the income is increasing.

# %%
# use the data to make the barplot  
# grouping variable that will produce elements with different colors
# add title,xlabel,ylabel to the plot

plt.figure(figsize=(10,5))
sns.barplot(x="Year", y="Average Wage", hue="Gender", data=gender).set_title('Average Wage by Gender and Year')
# Out:
# Text(0.5, 1.0, 'Average Wage by Gender and Year')

# %% [markdown]
# From the plot we can see that the the average wage per year didn't change obviously, and  male's wage is usually higher than female's.

# %% [markdown]
# #### Part 2: Income in race

# %%
#read the race csv file from Github
race = pd.read_csv('https://raw.githubusercontent.com/gegeli638/DAV-5400/master/final/Wage%20by%20Race%20and%20Ethnicity%20in%20Common%20Jobs.csv')

# to clean and transfer the data, we need to drop the data that we do not need 
race = race.drop(columns = ['ID Year','ID Race', 'Workforce Status','ID Workforce Status','ID Detailed Occupation','Average Wage Appx MOE','Total Population MOE Appx', 'Record Count','ID Geography'])

# use .head() to print the answer
race.head()
# Out:
#                 Race  Year                        Detailed Occupation  \
# 0  Two or More Races  2017                        Retail salespersons
# 1  Two or More Races  2017    Secretaries & administrative assistants
# 2  Two or More Races  2017  Nursing, psychiatric, & home health aides
# 3  Two or More Races  2017                     Miscellaneous managers
# 4  Two or More Races  2017        Elementary & middle school teachers
#
#    Average Wage  Total Population Geography
# 0   17561.84615              4953  New York
# 1   34295.05522              4962  New York
# 2   25519.74846              9923  New York
# 3  110063.70080              4225  New York
# 4   79445.16087              4948  New York

# %%
# use groupby to get the average wage of different race in differnet Occupations
race.groupby(['Detailed Occupation'])['Average Wage'].mean()
# Out:
# Detailed Occupation
# Elementary & middle school teachers          59882.354607
# Miscellaneous managers                       86552.750617
# Nursing, psychiatric, & home health aides    23876.516885
# Retail salespersons                          25396.394398
# Secretaries & administrative assistants      38658.626765
# Name: Average Wage, dtype: float64

# %% [markdown]
# From the statistical analysis, we can see the highest income occupation is miscellaneous managers and the total income average wage is 86552.750617. The lowest income occupation is nursing, psychiatric, & home health aides and the average wage is 23876.516885.

# %%
# use the data to get the barplot  
# Grouping variable that will produce elements with different colors
# add title,xlabel,ylabel to the plot
plt.figure(figsize=(20,7))
sns.barplot(x="Detailed Occupation", y="Average Wage", hue="Race", data=race).set_title('Average Wage by Job and Race')
# Out:
# Text(0.5, 1.0, 'Average Wage by Job and Race')

# %% [markdown]
# This graphic shows that in different jobs the earnings changed. The Miscellanoues managers has the highest average wage, and  Nursing, psychiatric & home health aids jobs earn least. Among different races, White people have the highest average wage, and the American Indian may be the cheapest labor.

# %% [markdown]
# #### Part 3: Income distribution and comparison in New York and the United State

# %%
#read the race csv file from Github
disrtibution = pd.read_csv('https://raw.githubusercontent.com/gegeli638/DAV-5400/master/final/Wage%20Distribution.csv')

# to clean and transfer the data, we need to drop the data that we do not need 
disrtibution = disrtibution.drop(columns = ['ID Year', 'Total Population MOE Appx', 'Slug Geography','Record Count'])

#sorted the data by the wage bin
disrtibution.sort_values('ID Wage Bin', inplace=True)

# use .head() to print the answer
disrtibution.head()
# Out:
#      ID Wage Bin Wage Bin  Year  ID Workforce Status  Workforce Status  \
# 167            1   < $10K  2014                 True              True
# 63             1   < $10K  2016                 True              True
# 65             1   < $10K  2016                 True              True
# 33             1   < $10K  2017                 True              True
# 21             1   < $10K  2017                 True              True
#
#      Total Population      Geography ID Geography     share
# 167           1096715       New York    04000US36  0.123042
# 63           18071160  United States      01000US  0.124292
# 65             996845       New York    04000US36  0.110766
# 33             948764       New York    04000US36  0.103788
# 21           17420601  United States      01000US  0.117932

# %%
# use the data to get the barplot  
# Grouping variable that will produce elements with different colors
# add title,xlabel,ylabel to the plot

plt.figure(figsize=(22,8))
sns.barplot(x="Wage Bin", y="share", hue="Geography", data=disrtibution).set_title('Proportion of Wage Distribution')
# Out:
# Text(0.5, 1.0, 'Proportion of Wage Distribution')

# %% [markdown]
# This chart shows the number of workers in New York across various wage buckets compared to the national average. Most people's wages are concentrated below 70K in the whole country. Above wage bin 50k to 60k, the number of workers in New York begins to more than the United States. But for the lower wage distribution, the proportion of people in the US is higher than NY, which means that people in NY are more likely to earn the most.

# %% [markdown]
# #### Part 4: Income in different county in New York

# %%
#read the race csv file from Github
income = pd.read_csv('https://raw.githubusercontent.com/gegeli638/DAV-5400/master/final/Median%20Household%20Income.csv')
#use .head() to print the answer
income.head()
# Out:
#    ID Year  Year  Household Income by Race            Geography  ID Geography  \
# 0     2017  2017                     79201  Richmond County, NY  05000US36085
# 1     2017  2017                     37397     Bronx County, NY  05000US36005
# 2     2017  2017                     85071  New York County, NY  05000US36061
# 3     2017  2017                     64509    Queens County, NY  05000US36081
# 4     2017  2017                     56942     Kings County, NY  05000US36047
#
#        Slug Geography
# 0  richmond-county-ny
# 1     bronx-county-ny
# 2  new-york-county-ny
# 3    queens-county-ny
# 4     kings-county-ny

# %%
#import geocoder to get the latitude&logitude of each county in the dataframe
import geocoder
#use a for loop to get the latitude&ongitude
for i in income['Geography']:
    g = geocoder.arcgis(i)
    print(g.latlng)
# Out:
# [40.58076996900007, -74.15532724299999]
# [40.84985000000006, -73.86640999999997]
# [40.71455000000003, -74.00713999999994]
# [40.71150317400003, -73.81994170099995]
# [40.650100000000066, -73.94957999999997]
# [40.650100000000066, -73.94957999999997]
# [40.58076996900007, -74.15532724299999]
# [40.84985000000006, -73.86640999999997]
# [40.71455000000003, -74.00713999999994]
# [40.71150317400003, -73.81994170099995]
# [40.71150317400003, -73.81994170099995]
# [40.650100000000066, -73.94957999999997]
# [40.84985000000006, -73.86640999999997]
# [40.58076996900007, -74.15532724299999]
# [40.71455000000003, -74.00713999999994]
# [40.650100000000066, -73.94957999999997]
# [40.71455000000003, -74.00713999999994]
# [40.84985000000006, -73.86640999999997]
# [40.71150317400003, -73.81994170099995]
# [40.58076996900007, -74.15532724299999]
# [40.71150317400003, -73.81994170099995]
# [40.58076996900007, -74.15532724299999]
# [40.84985000000006, -73.86640999999997]
# [40.650100000000066, -73.94957999999997]
# [40.71455000000003, -74.00713999999994]

# %%
#import a folum to draw the map
import folium

#set the map location, zoom start size, tiles and the width
folium_map = folium.Map(location=[40.71455000000003, -74.00713999999994],
                        zoom_start=10,
                        tiles="CartoDB dark_matter",
                        width='50%')

# for each row in the data, add a cicle marker
#use a for loop to get each county's latitude and logitude
for index, row in income.iterrows():
    g = geocoder.arcgis(row['Geography'])
    

# generate the popup message that is shown on click.
    popup_text = "Year:{} <br> Household Income by Race:{} <br> Place:{}"
    popup_text = popup_text.format(row['Year'],
                                   row["Household Income by Race"],
                                   row["Geography"])

        
# radius of circles
    radius = row["Household Income by Race"] / 10    
    
# choose the color of the marker
#use if, elseif and else to seperate each year's color
    if row["Year"] == 2017:
        color="#E37222" 
    elif row["Year"] == 2016:
        color="#0A8A9F" 
    elif row["Year"] == 2015:
        color="#00FA9A"
    elif row["Year"] == 2014:
        color="#FFF8DC"
    else:
        color="#FF0000" 
        
# add marker to the map
    folium.Circle(location=(g.latlng),
                            radius=radius,
                            color=color,
                            popup=popup_text,
                            fill=True).add_to(folium_map)      

#print the folium map
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From the map we can see five counties in NY: Richmond County, NY, Bronx County, NY, New York County, NY, Queens County, NY and Kings County, NY. When the circle is bigger, which means the household income is higher. We can see that the biggest circle is in New York county and the smallest circle is in Bronx county. That means people in Manhattan earns more than Bronx, that makes sense. When click the circle, we can see the different household income in each year. All the five counties' household income increase by years. And the highest household income is in New York county in 2017.

# %% [markdown]
# ### Expenditure data anaysis in New York
# #### Part 1: recent years expenditure trend

# %%
#use the web api
url = 'https://api.opendatanetwork.com/data/v1/values?app_token=cQovpGcdUT1CSzgYk0KPYdAI0&describe=true&forecast=5&format=google&variable=economy.consumption.personal_consumption_expenditures&entity_id=0400000US42%2C0400000US36'
#test wether it worked
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
#convert data to JSON
data = resp.json()
data
# Out:
# {'data': {'rows': [{'c': [{'v': 1997},
#      {'v': 412421, 'f': '$412,421 (Measured)'},
#      {'v': True},
#      {'v': 248278, 'f': '$248,278 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 1998},
#      {'v': 435412, 'f': '$435,412 (Measured)'},
#      {'v': True},
#      {'v': 261665, 'f': '$261,665 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 1999},
#      {'v': 463769, 'f': '$463,769 (Measured)'},
#      {'v': True},
#      {'v': 277253, 'f': '$277,253 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2000},
#      {'v': 496495, 'f': '$496,495 (Measured)'},
#      {'v': True},
#      {'v': 296305, 'f': '$296,305 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2001},
#      {'v': 518273, 'f': '$518,273 (Measured)'},
#      {'v': True},
#      {'v': 309684, 'f': '$309,684 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2002},
#      {'v': 535432, 'f': '$535,432 (Measured)'},
#      {'v': True},
#      {'v': 320981, 'f': '$320,981 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2003},
#      {'v': 562955, 'f': '$562,955 (Measured)'},
#      {'v': True},
#      {'v': 339358, 'f': '$339,358 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2004},
#      {'v': 595605, 'f': '$595,605 (Measured)'},
#      {'v': True},
#      {'v': 357580, 'f': '$357,580 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2005},
#      {'v': 632211, 'f': '$632,211 (Measured)'},
#      {'v': True},
#      {'v': 376511, 'f': '$376,511 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2006},
#      {'v': 664060, 'f': '$664,060 (Measured)'},
#      {'v': True},
#      {'v': 394583, 'f': '$394,583 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2007},
#      {'v': 695777, 'f': '$695,777 (Measured)'},
#      {'v': True},
#      {'v': 412343, 'f': '$412,343 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2008},
#      {'v': 717323, 'f': '$717,323 (Measured)'},
#      {'v': True},
#      {'v': 426513, 'f': '$426,513 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2009},
#      {'v': 710033, 'f': '$710,033 (Measured)'},
#      {'v': True},
#      {'v': 422480, 'f': '$422,480 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2010},
#      {'v': 739205, 'f': '$739,205 (Measured)'},
#      {'v': True},
#      {'v': 437128, 'f': '$437,128 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2011},
#      {'v': 773000, 'f': '$773,000 (Measured)'},
#      {'v': True},
#      {'v': 455954, 'f': '$455,954 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2012},
#      {'v': 794283, 'f': '$794,283 (Measured)'},
#      {'v': True},
#      {'v': 468272, 'f': '$468,272 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2013},
#      {'v': 822169, 'f': '$822,169 (Measured)'},
#      {'v': True},
#      {'v': 479054, 'f': '$479,054 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2014},
#      {'v': 863447, 'f': '$863,447 (Measured)'},
#      {'v': True},
#      {'v': 493704, 'f': '$493,704 (Measured)'},
#      {'v': True}]},
#    {'c': [{'v': 2015},
#      {'v': 889977.9411764706, 'f': '$889,978 (Forecasted)'},
#      {'v': False},
#      {'v': 508140.82352941175, 'f': '$508,141 (Forecasted)'},
#      {'v': False}]},
#    {'c': [{'v': 2016},
#      {'v': 916508.8823529412, 'f': '$916,509 (Forecasted)'},
#      {'v': False},
#      {'v': 522577.64705882355, 'f': '$522,578 (Forecasted)'},
#      {'v': False}]},
#    {'c': [{'v': 2017},
#      {'v': 943039.8235294118, 'f': '$943,040 (Forecasted)'},
#      {'v': False},
#      {'v': 537014.4705882353, 'f': '$537,014 (Forecasted)'},
#      {'v': False}]},
#    {'c': [{'v': 2018},
#      {'v': 969570.7647058824, 'f': '$969,571 (Forecasted)'},
#      {'v': False},
#      {'v': 551451.2941176471, 'f': '$551,451 (Forecasted)'},
#      {'v': False}]},
#    {'c': [{'v': 2019},
#      {'v': 996101.705882353, 'f': '$996,102 (Forecasted)'},
#      {'v': False},
#      {'v': 565888.1176470588, 'f': '$565,888 (Forecasted)'},
#      {'v': False}]}],
#   'cols': [{'id': 'year', 'type': 'string'},
#    {'id': '0400000US36', 'type': 'number', 'label': 'New York'},
#    {'id': 'forecast', 'type': 'boolean', 'role': 'certainty'},
#    {'id': '0400000US42', 'type': 'number', 'label': 'Pennsylvania'},
#    {'id': 'forecast', 'type': 'boolean', 'role': 'certainty'}]},
#  'description': 'The personal consumption expenditure of New York was $412,421 in 1997. The personal consumption expenditure of Pennsylvania was $248,278 in 1997. The personal consumption expenditure of New York was $435,412 in 1998. The personal consumption expenditure of Pennsylvania was $261,665 in 1998. The personal consumption expenditure of New York was $463,769 in 1999. The personal consumption expenditure of Pennsylvania was $277,253 in 1999. The personal consumption expenditure of New York was $496,495 in 2000. The personal consumption expenditure of Pennsylvania was $296,305 in 2000. The personal consumption expenditure of New York was $518,273 in 2001. The personal consumption expenditure of Pennsylvania was $309,684 in 2001. The personal consumption expenditure of New York was $535,432 in 2002. The personal consumption expenditure of Pennsylvania was $320,981 in 2002. The personal consumption expenditure of New York was $562,955 in 2003. The personal consumption expenditure of Pennsylvania was $339,358 in 2003. The personal consumption expenditure of New York was $595,605 in 2004. The personal consumption expenditure of Pennsylvania was $357,580 in 2004. The personal consumption expenditure of New York was $632,211 in 2005. The personal consumption expenditure of Pennsylvania was $376,511 in 2005. The personal consumption expenditure of New York was $664,060 in 2006. The personal consumption expenditure of Pennsylvania was $394,583 in 2006. The personal consumption expenditure of New York was $695,777 in 2007. The personal consumption expenditure of Pennsylvania was $412,343 in 2007. The personal consumption expenditure of New York was $717,323 in 2008. The personal consumption expenditure of Pennsylvania was $426,513 in 2008. The personal consumption expenditure of New York was $710,033 in 2009. The personal consumption expenditure of Pennsylvania was $422,480 in 2009. The personal consumption expenditure of New York was $739,205 in 2010. The personal consumption expenditure of Pennsylvania was $437,128 in 2010. The personal consumption expenditure of New York was $773,000 in 2011. The personal consumption expenditure of Pennsylvania was $455,954 in 2011. The personal consumption expenditure of New York was $794,283 in 2012. The personal consumption expenditure of Pennsylvania was $468,272 in 2012. The personal consumption expenditure of New York was $822,169 in 2013. The personal consumption expenditure of Pennsylvania was $479,054 in 2013. The personal consumption expenditure of New York was $863,447 in 2014. The personal consumption expenditure of Pennsylvania was $493,704 in 2014.',
#  'forecast_descriptions': ['The last measured personal consumption expenditure for New York was $863,447 in 2014. New York experienced an average growth rate of 6.43% from our first statistic recorded in 1997. If past trends continue, we forecast the personal consumption expenditure to be $996,102 by 2019.',
#   'The last measured personal consumption expenditure for Pennsylvania was $493,704 in 2014. Pennsylvania experienced an average growth rate of 5.81% from our first statistic recorded in 1997. If past trends continue, we forecast the personal consumption expenditure to be $565,888 by 2019.']}

# %% [markdown]
# From this web api describtion, we can see that the value in 2015-2019 are forecasted. Cause we are now in 2019, compare the recent years economy, so we can treat the forecasted data as real.

# %%
# Extracted the content started from result
results = data['data']
results
# delete unuseful column and only choose the data we want
a = results['rows']
a
# Out:
# [{'c': [{'v': 1997},
#    {'v': 412421, 'f': '$412,421 (Measured)'},
#    {'v': True},
#    {'v': 248278, 'f': '$248,278 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 1998},
#    {'v': 435412, 'f': '$435,412 (Measured)'},
#    {'v': True},
#    {'v': 261665, 'f': '$261,665 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 1999},
#    {'v': 463769, 'f': '$463,769 (Measured)'},
#    {'v': True},
#    {'v': 277253, 'f': '$277,253 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2000},
#    {'v': 496495, 'f': '$496,495 (Measured)'},
#    {'v': True},
#    {'v': 296305, 'f': '$296,305 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2001},
#    {'v': 518273, 'f': '$518,273 (Measured)'},
#    {'v': True},
#    {'v': 309684, 'f': '$309,684 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2002},
#    {'v': 535432, 'f': '$535,432 (Measured)'},
#    {'v': True},
#    {'v': 320981, 'f': '$320,981 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2003},
#    {'v': 562955, 'f': '$562,955 (Measured)'},
#    {'v': True},
#    {'v': 339358, 'f': '$339,358 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2004},
#    {'v': 595605, 'f': '$595,605 (Measured)'},
#    {'v': True},
#    {'v': 357580, 'f': '$357,580 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2005},
#    {'v': 632211, 'f': '$632,211 (Measured)'},
#    {'v': True},
#    {'v': 376511, 'f': '$376,511 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2006},
#    {'v': 664060, 'f': '$664,060 (Measured)'},
#    {'v': True},
#    {'v': 394583, 'f': '$394,583 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2007},
#    {'v': 695777, 'f': '$695,777 (Measured)'},
#    {'v': True},
#    {'v': 412343, 'f': '$412,343 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2008},
#    {'v': 717323, 'f': '$717,323 (Measured)'},
#    {'v': True},
#    {'v': 426513, 'f': '$426,513 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2009},
#    {'v': 710033, 'f': '$710,033 (Measured)'},
#    {'v': True},
#    {'v': 422480, 'f': '$422,480 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2010},
#    {'v': 739205, 'f': '$739,205 (Measured)'},
#    {'v': True},
#    {'v': 437128, 'f': '$437,128 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2011},
#    {'v': 773000, 'f': '$773,000 (Measured)'},
#    {'v': True},
#    {'v': 455954, 'f': '$455,954 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2012},
#    {'v': 794283, 'f': '$794,283 (Measured)'},
#    {'v': True},
#    {'v': 468272, 'f': '$468,272 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2013},
#    {'v': 822169, 'f': '$822,169 (Measured)'},
#    {'v': True},
#    {'v': 479054, 'f': '$479,054 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2014},
#    {'v': 863447, 'f': '$863,447 (Measured)'},
#    {'v': True},
#    {'v': 493704, 'f': '$493,704 (Measured)'},
#    {'v': True}]},
#  {'c': [{'v': 2015},
#    {'v': 889977.9411764706, 'f': '$889,978 (Forecasted)'},
#    {'v': False},
#    {'v': 508140.82352941175, 'f': '$508,141 (Forecasted)'},
#    {'v': False}]},
#  {'c': [{'v': 2016},
#    {'v': 916508.8823529412, 'f': '$916,509 (Forecasted)'},
#    {'v': False},
#    {'v': 522577.64705882355, 'f': '$522,578 (Forecasted)'},
#    {'v': False}]},
#  {'c': [{'v': 2017},
#    {'v': 943039.8235294118, 'f': '$943,040 (Forecasted)'},
#    {'v': False},
#    {'v': 537014.4705882353, 'f': '$537,014 (Forecasted)'},
#    {'v': False}]},
#  {'c': [{'v': 2018},
#    {'v': 969570.7647058824, 'f': '$969,571 (Forecasted)'},
#    {'v': False},
#    {'v': 551451.2941176471, 'f': '$551,451 (Forecasted)'},
#    {'v': False}]},
#  {'c': [{'v': 2019},
#    {'v': 996101.705882353, 'f': '$996,102 (Forecasted)'},
#    {'v': False},
#    {'v': 565888.1176470588, 'f': '$565,888 (Forecasted)'},
#    {'v': False}]}]

# %%
#when reading the descirbtion of the web api, we want to 
#select the column: 'year','New York expenditure','Pennsylvania expenditure'

#create new lists
year = []
NY = []
Penn = []

#use a for loop to expand the list
for c in range(len(a)):
    cc = a[c]['c']
    #print(cc) 
    year.append(cc[0]['v'])
    NY.append(cc[1]['v'])
    Penn.append(cc[3]['v'])
    
#show the column name   
dict = {'year':year , 'NY':NY , 'Penn':Penn}

#print the new data into dataframe named Top
Top = pd.DataFrame(dict, columns=['year','NY','Penn'])
Top
# Out:
#     year             NY           Penn
# 0   1997  412421.000000  248278.000000
# 1   1998  435412.000000  261665.000000
# 2   1999  463769.000000  277253.000000
# 3   2000  496495.000000  296305.000000
# 4   2001  518273.000000  309684.000000
# 5   2002  535432.000000  320981.000000
# 6   2003  562955.000000  339358.000000
# 7   2004  595605.000000  357580.000000
# 8   2005  632211.000000  376511.000000
# 9   2006  664060.000000  394583.000000
# 10  2007  695777.000000  412343.000000
# 11  2008  717323.000000  426513.000000
# 12  2009  710033.000000  422480.000000
# 13  2010  739205.000000  437128.000000
# 14  2011  773000.000000  455954.000000
# 15  2012  794283.000000  468272.000000
# 16  2013  822169.000000  479054.000000
# 17  2014  863447.000000  493704.000000
# 18  2015  889977.941176  508140.823529
# 19  2016  916508.882353  522577.647059
# 20  2017  943039.823529  537014.470588
# 21  2018  969570.764706  551451.294118
# 22  2019  996101.705882  565888.117647

# %%
#draw a line plot the show the trend in recent year

#use figsize to decide the plot size
plt.figure(figsize=(20,5))
#add xlable as year and data from NY expenditure
plt.plot(Top['year'],Top['NY'],marker='o',label=u'NY')
#add xlable as year and data from Penn expenditure
plt.plot(Top['year'],Top['Penn'],marker='*',label=u'Penn')
#draw the legend()
plt.legend()
#set the x axis from 1997 to 2020 so that we can see the exact expenditure in 1997-2019
x = range(1997,2020,1)

#show the plt
plt.xticks(x,x)
plt.show()

# %% [markdown]
# From the lineplot we can see that the expenses in NY and Penn incresed all the time from 1997 to 2019, except for in 2008 which experienced a financial crisis. We compare NY and Penn because in the next part we will also compare NY and Washington, D.C. to the United State.

# %% [markdown]
# #### Part 2: Three most important expenses comparison(housing, transportation, food)

# %%
#Scrap the web page into the html file and upload the html file to Github
#read Github to get the html data
tables = pd.read_html('https://raw.githubusercontent.com/gegeli638/DAV-5400/master/final/html.html')

#the first item in the list is a data frame
html = tables[0]
html.head()
# Out:
#             Area  Housing  Transportation  Food
# 0  United States     33.0            16.0  12.9
# 1      Anchorage     31.5            15.7  12.6
# 2        Atlanta     32.8            16.3  11.5
# 3      Baltimore     32.3            15.8  11.9
# 4         Boston     37.5            12.0  12.1

# %%
# since the value of the html is strign, we need to clean the dataframe and transfer 
# the string values of Housing,Transportation and Food columns to int

html['Housing'] = pd.to_numeric(html['Housing'])
html['Transportation'] = pd.to_numeric(html['Transportation'])
html['Food'] = pd.to_numeric(html['Food'])

# to test the data type
#html['Food'].head()

# %%
# get the total expenses of Housing,Transportation,Food

html['Total'] = html.sum(axis=1)
html
# Out:
#                     Area  Housing  Transportation  Food  Total
# 0          United States     33.0            16.0  12.9   61.9
# 1              Anchorage     31.5            15.7  12.6   59.8
# 2                Atlanta     32.8            16.3  11.5   60.6
# 3              Baltimore     32.3            15.8  11.9   60.0
# 4                 Boston     37.5            12.0  12.1   61.6
# 5                Chicago     35.3            13.2  13.3   61.8
# 6      Dallas-Fort Worth     36.7            16.8  11.1   64.6
# 7                 Denver     34.2            15.2  12.4   61.8
# 8                Detroit     30.1            19.3  12.3   61.7
# 9               Honolulu     38.0            10.9  18.1   67.0
# 10               Houston     34.1            15.9  11.8   61.8
# 11           Los Angeles     35.7            13.6  13.2   62.5
# 12                 Miami     37.3            15.3  11.8   64.4
# 13  Minneapolis-St. Paul     33.6            12.9  11.6   58.1
# 14              New York     39.0            12.0  12.3   63.3
# 15          Philadelphia     32.8            15.6  12.6   61.0
# 16               Phoenix     31.0            19.0  11.7   61.7
# 17             San Diego     35.9            14.3  13.3   63.5
# 18         San Francisco     39.4            11.3  12.6   63.3
# 19               Seattle     34.5            14.1  13.4   62.0
# 20             St. Louis     32.9            15.1  11.7   59.7
# 21                 Tampa     35.5            15.3  14.3   65.1
# 22      Washington, D.C.     33.9            14.4  12.3   60.6

# %%
# to get the city which has the max total percentage 

max_html = html[html['Total'] == max(html['Total'])]
max_html
# Out:
#        Area  Housing  Transportation  Food  Total
# 9  Honolulu     38.0            10.9  18.1   67.0

# %% [markdown]
# We choose the max total percentage city in the html dataframe, which is Honolulu. Honolulu is in Hawaii and for island housing and food may be more difficult to get than other cities. That makes sense.

# %%
# to get the city which has the min total percentage 

min_html = html[html['Total'] == min(html['Total'])]
min_html
# Out:
#                     Area  Housing  Transportation  Food  Total
# 13  Minneapolis-St. Paul     33.6            12.9  11.6   58.1

# %% [markdown]
# For the min total percentage city is Minneapolis-Saint Paul which is built around the Mississippi, Minnesota and St. Croix rivers in east central Minnesota. This city is in low total expenditure because the economic level is not high.

# %%
#for further analysis, we need tidy data
# convert the data from wide to long

#melt the dataframe that each row only contains one value
html1 = html.melt(id_vars = ["Area"], value_vars = ['Housing','Transportation','Food','Total'])
#test and print the answer
html1.head()
# Out:
#             Area variable  value
# 0  United States  Housing   33.0
# 1      Anchorage  Housing   31.5
# 2        Atlanta  Housing   32.8
# 3      Baltimore  Housing   32.3
# 4         Boston  Housing   37.5

# %%
# select column: United States,New York and Washington, D.C. 
# extract these three column to do comparison analysis

comparison = html1[(html1.Area == 'United States')|(html1.Area == 'New York')|(html1.Area == 'Washington, D.C.')]
comparison
# Out:
#                 Area        variable  value
# 0      United States         Housing   33.0
# 14          New York         Housing   39.0
# 22  Washington, D.C.         Housing   33.9
# 23     United States  Transportation   16.0
# 37          New York  Transportation   12.0
# 45  Washington, D.C.  Transportation   14.4
# 46     United States            Food   12.9
# 60          New York            Food   12.3
# 68  Washington, D.C.            Food   12.3
# 69     United States           Total   61.9
# 83          New York           Total   63.3
# 91  Washington, D.C.           Total   60.6

# %%
# use the data to get the barplot  
# Grouping variable that will produce elements with different colors
# add title,xlabel,ylabel to the plot

plt.figure(figsize=(10,5))

sns.barplot(x='variable',y='value',hue="Area",data=comparison).set_title('comparison of expenditures')
# Out:
# Text(0.5, 1.0, 'comparison of expenditures')

# %% [markdown]
# From this plot we can see that in housing proportion, NY is higher than the United States and Washington. But in transportation, NY is lower than the United States and Washington. That means in New York housing expenses is very high but New York transportation is very convenience. For the total consumption is almost 60%, which means in the US people still have additional money to enjoy their life. Also, in NY the total expenditure is higher than in the US.

# %% [markdown]
# ### Conclusion
# In conclusion, we use real data to verify the truth that people's income and expenditure increased year by year. For income, the average male's salary is always higher than the female's. There is also a difference in races, occupations, and counties. For expenditure, people's necessary expenditure for our daily life only takes up 62%, which means people in the US have a relatively higher living standard. Overall, although the personal income and expenditure in New York are both high, people still get extra money to enjoy their life.
